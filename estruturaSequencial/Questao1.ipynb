# %% [markdown]
# # Faça um Programa que mostre a mensagem "Alo mundo" na tela.

# %% [markdown]
# ##Resposta:
#
# Escreva (“Alo mundo”)

# %% [markdown]
# ##Dicas/Comentários:
# Lembre-se todo texto que deverá ser exibido na tela, deverá estar entre aspas, duplas ou simples.
#
# Para te ajudar:
#
#
# *   aspas simples: ‘a’ somente um caracter, podendo ser: letra, número ou caractere especial, como: !
# *   aspas duplas: “palavra”, mais de um carácter.
#
# Tudo que estiver fora das aspas, o programa entenderá como variável.
#
# Utilizaremos o comando abaixo para realizar a programação:
# * print()
#
# Não se esqueça dos parenteses!

# %%
print("Alo mundo")
# Out:
# Alo mundo
